# %% [markdown]
# <a href="https://colab.research.google.com/github/padmathanumoorthy/gemini/blob/master/Gen_text_from_image_GeminiProVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
from google.colab import userdata
genai.configure(api_key=userdata.get('API_KEY'))

# %% [markdown]
# # Generating Text from Image and Text Inputs: GeminiProVision
#
# PIL - python image lib - free and opensource (all env)

# %%
pip install -q pillow

# %%
from PIL import Image

# %%
#put the picture in the content/..
img = Image.open("/content/benji.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=793x412>

# %%
import google.generativeai as genai
from google.colab import userdata
genai.configure(api_key=userdata.get('API_KEY'))

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content(img) #just sending image as prompt

# %%
print(response.text)
# Out:
#  The puppy seems to be enjoying the cucumber.

# %%
prompt= 'describe this image for me'
response = model.generate_content([img, prompt])
print(response.text)
# Out:
#  A small brown toy poodle eats a piece of cucumber held by a light-skinned human hand. The dog appears to be in a kitchen, with beige tile flooring and a brown wall.

# %%
prompt= 'who is feeding the puppy'
response = model.generate_content([img, prompt])
print(response.text)
# Out:
#  A person is feeding the puppy. The person's hand is holding a piece of cucumber, which the puppy is eating. The puppy is a small, brown dog with curly hair. The person is not visible in the photo, but their hand is holding the cucumber in front of the puppy's mouth. The puppy is looking up at the cucumber with its mouth open.
